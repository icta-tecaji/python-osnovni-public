# %% [markdown]
# # Nek naslov
#
# ## Podnaslov
#
# ### Podpodnaslov
#
#
# Neko besedilo tralala

# %%
import pandas as pd # Za branje podatkov in obdelovanje le teh v obliki tabele (DataFrame)
import numpy as np # Za optimizirano/vektorizirano delo s arrayi številk
from tqdm.notebook import tqdm # Za izris kje v itarciji smo z zanko
import matplotlib.pyplot as plt # Za izrisovanje grafov/slik
import time

# %%
[1,2,4] * 3
# Out:
# [1, 2, 4, 1, 2, 4, 1, 2, 4]

# %%
x = [
    [3,67,9],
    [3,8,8]
]
x = np.array(x)*5
x[1:2,:2]
# Out:
# array([[15, 40]])

# %%
x = [("Anže",66),("Nejc",105),("Jože",98)]

# %%
sorted(x,key=lambda x: x[1],reverse=True)
# Out:
# [('Nejc', 105), ('Jože', 98), ('Anže', 66)]

# %%
class Pes:
    def __init__(self,starost):
        self.starost =starost

psi = [Pes(6),Pes(12),Pes(20),Pes(1),Pes(0.1),Pes(99),Pes(-1)]


def vrni_starost(objekt):
    return objekt.starost

[y.starost for y in sorted(psi,key=lambda x: x.starost)]
# [y.starost for y in sorted(psi,key=vrni_starost)]
# Out:
# [-1, 0.1, 1, 6, 12, 20, 99]

# %%
def fun(vrednost):
    return vrednost*3

fun(5)
# Out:
# 15

# %%
x = fun

# %%
x(5)
# Out:
# 15

# %%
print(id(fun))
print(id(x))
# Out:
# 1914301293376
# 1914301293376

# %%
x = lambda x: x*3
x(5)
# Out:
# 15

# %%
data = [1,2,3,4,5,6,88,100]
# for x in tqdm(range(574544576)):
for x in tqdm(data):
    print(x)
    time.sleep(0.5)
    pass
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# 1
# 2
# 3
# 4
# 5
# 6
# 88
# 100

# %%
arr = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
np.array(arr)*2
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12],
#        [14, 16, 18]])

# %%
img = np.random.rand(10,10,3)

plt.figure() # definiramo/kreiramo območje za sliko "konkstruktor"
plt.imshow(img) # display image on "figure"
plt.tick_params(labelrotation=90)
plt.title("Moja druga random slika")
plt.show() # prikažiu kar sem shranil v "figure"

# %%
# 
#
#
fig, axs = plt.subplots(nrows=2,ncols=2,figsize=(10,10))
axs[0,0].imshow(np.random.rand(5,5,3))
axs[0,1].imshow(np.random.rand(5,5,3)*0.5)
axs[1,0].imshow(np.random.rand(5,5,3)*1.5)
axs[1,1].imshow(np.random.rand(5,5,3)*0.1)
# axs[0,0].set_yticks([4,5,6,7,8],labelrotation=90)
axs[0,0].invert_yaxis()
axs[0,1].invert_yaxis()
axs[1,0].invert_yaxis()
axs[1,1].invert_yaxis()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01226646466551562..1.4994190446817557].

# %%
plt.figure(figsize=(10,5))
plt.plot(np.sin(np.arange(-10,10,0.1)),"-.g")
plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
podatki = pd.read_excel("../test.xlsx")
podatki = podatki.reset_index()
del podatki["index"]
podatki = podatki[podatki["StolpecF"]>60]
podatki["moj_novi_stolpec"] = podatki["StolpecD"] + podatki["StolpecF"]
podatki
# Out:
#     StolpecD  StolpecE  StolpecF  moj_novi_stolpec
# 7          8      1570     66.00             74.00
# 8          9      1770     74.25             83.25
# 9         10      1970     82.50             92.50
# 10        11      2170     90.75            101.75
# 11        12      2370     99.00            111.00

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
import time

def pltsin(ax, colors=['b']):
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        for color in colors:
            y = np.random.random(size=(100,1))
            ax.plot(x, y, color)
    fig.canvas.draw()

fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
plt.show()

# run this cell to dynamically update plot
for f in range(500):
    pltsin(ax, ['b', 'r'])
    time.sleep(1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 29
#      27 for f in range(500):
#      28     pltsin(ax, ['b', 'r'])
# ---> 29     time.sleep(1)
#
# KeyboardInterrupt:
